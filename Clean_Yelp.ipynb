# %% [markdown]
# ## Preparation

# %%
# Using SQL + Pandas
import pandas as pd
import sqlite3

# Data Visualization
from plotnine import *
import seaborn as sns
import matplotlib.pyplot as plt

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Read in the data
DC_Yelp = pd.read_csv("Data/Yelp/DC_Yelp.csv")
Chicago_Yelp = pd.read_csv("Data/Yelp/Chicago_Yelp.csv")
NY_Yelp = pd.read_csv("Data/Yelp/NY_Yelp.csv")
SF_Yelp = pd.read_csv("Data/Yelp/SF_Yelp.csv")
LA_Yelp = pd.read_csv("Data/Yelp/LA_Yelp.csv")

# %% [markdown]
# ## Clean DC_Yelp

# %%
# View the head of the data
DC_Yelp.head()
# Out:
#                               business_name           rating  review_count  \
# 0  Crystal City Restaurant Gentleman’s Club    3 star rating            83
# 1                            201. Due South  3.5 star rating           548
# 2                    202. Shawarma District  4.5 star rating            43
# 3                      203. Moh Moh Licious  4.5 star rating            78
# 4              204. The Best Sandwich Place  4.5 star rating            56
#
#                            price_category
# 0     $$American (New), Bars, Strip Clubs
# 1                    $$Southern, Barbeque
# 2            $Mediterranean, Salad, Wraps
# 3       $Himalayan/Nepalese, Asian Fusion
# 4  $Breakfast & Brunch, Sandwiches, Wraps

# %%
# Print the shape of the data
DC_Yelp.shape
# Out:
# (262, 4)

# %%
# Get the repeated ad business
ad = DC_Yelp.business_name[0]

# Remove the repeated ad business
DC_Yelp = DC_Yelp[DC_Yelp.business_name != ad].reset_index(drop=True)

DC_Yelp
# Out:
#                     business_name           rating  review_count  \
# 0                  201. Due South  3.5 star rating           548
# 1          202. Shawarma District  4.5 star rating            43
# 2            203. Moh Moh Licious  4.5 star rating            78
# 3    204. The Best Sandwich Place  4.5 star rating            56
# 4                   205. Pho Viet    4 star rating           710
# ..                            ...              ...           ...
# 235        46. Dumplings & Beyond    4 star rating           434
# 236             47. Pisco Y Nazca  4.5 star rating           829
# 237                 48. Bad Saint    4 star rating           605
# 238  49. Busboys and Poets - 450K    4 star rating          2353
# 239                   50. Maketto    4 star rating           972
#
#                                         price_category
# 0                                 $$Southern, Barbeque
# 1                         $Mediterranean, Salad, Wraps
# 2                    $Himalayan/Nepalese, Asian Fusion
# 3               $Breakfast & Brunch, Sandwiches, Wraps
# 4                                         $$Vietnamese
# ..                                                 ...
# 235                                          $$Chinese
# 236                          $$Peruvian, Cocktail Bars
# 237                                        $$$Filipino
# 238  $$American (Traditional), Breakfast & Brunch, ...
# 239                      $$Cafes, Cambodian, Taiwanese
#
# [240 rows x 4 columns]

# %%
# Split business_name into two columns
DC_Yelp[['index','business_name']] = (DC_Yelp
                                      .business_name
                                      .str
                                      .split(".\xa0",expand=True))

# Convert index to int
DC_Yelp['index'] = DC_Yelp['index'].astype(int)

# Sort values along index
DC_Yelp = (DC_Yelp
           .sort_values('index')
           .drop('index',axis=1)
           .reset_index(drop=True))

DC_Yelp
# Out:
#                                business_name           rating  review_count  \
# 0                               Le Diplomate  4.5 star rating          3596
# 1                              Gypsy Kitchen  4.5 star rating            70
# 2                               Butter Me Up  4.5 star rating           103
# 3                                  The Block    5 star rating            12
# 4                                  The Alibi  4.5 star rating           441
# ..                                       ...              ...           ...
# 235                             Logan Tavern    4 star rating           872
# 236                                      Uzu  4.5 star rating            87
# 237                 Akira Ramen & Izakaya DC  4.5 star rating            49
# 238  City Kabob and Curry House - Washington  4.5 star rating           138
# 239                                   Barrel  4.5 star rating           754
#
#                                         price_category
# 0            $$$Brasseries, French, Breakfast & Brunch
# 1                    Tapas/Small Plates, Mediterranean
# 2                                   Breakfast & Brunch
# 3                       Food Court, Bars, Asian Fusion
# 4                         $$Pubs, Sandwiches, Barbeque
# ..                                                 ...
# 235  $$American (New), Sports Bars, American (Tradi...
# 236                                            $$Ramen
# 237                                            $$Ramen
# 238                         $$Pakistani, Indian, Halal
# 239  $$American (New), Cocktail Bars, Breakfast & B...
#
# [240 rows x 4 columns]
