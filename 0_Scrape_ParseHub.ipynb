# %%
# Using SQL + Pandas
import pandas as pd
import numpy as np

# Data Visualization
from plotnine import *
import seaborn as sns
import matplotlib.pyplot as plt

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Read in the data
DC_urls = pd.read_csv("Data/ParseHub/DC_urls.csv")

# %%
# Select every 10th row
DC_urls_sample = DC_urls.iloc[::10,:]
DC_urls_sample
# Out:
#                                                   urls
# 0    https://www.yelp.com/search?find_desc=&find_lo...
# 10   https://www.yelp.com/search?find_desc=&find_lo...
# 20   https://www.yelp.com/search?find_desc=&find_lo...
# 30   https://www.yelp.com/search?find_desc=&find_lo...
# 40   https://www.yelp.com/search?find_desc=&find_lo...
# 50   https://www.yelp.com/search?find_desc=&find_lo...
# 60   https://www.yelp.com/search?find_desc=&find_lo...
# 70   https://www.yelp.com/search?find_desc=&find_lo...
# 80   https://www.yelp.com/search?find_desc=&find_lo...
# 90   https://www.yelp.com/search?find_desc=&find_lo...
# 100  https://www.yelp.com/search?find_desc=&find_lo...
# 110  https://www.yelp.com/search?find_desc=&find_lo...
# 120  https://www.yelp.com/search?find_desc=&find_lo...
# 130  https://www.yelp.com/search?find_desc=&find_lo...
# 140  https://www.yelp.com/search?find_desc=&find_lo...
# 150  https://www.yelp.com/search?find_desc=&find_lo...
# ...

# %%
# Export DC_urls_sample to a CSV file
DC_urls_sample.to_csv('Data/ParseHub/DC_urls_sample.csv',index=False)
