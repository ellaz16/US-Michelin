# %% [markdown]
# ## Preparation

# %%
# Using SQL + Pandas
import pandas as pd
import numpy as np

# Data Visualization
from plotnine import *
import seaborn as sns
import matplotlib.pyplot as plt

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Clean PH_DC

# %%
# Read in the data
PH_DC = pd.read_csv("Data/ParseHub/PH_DC.csv")

# %%
# View the head of the data
PH_DC.head()
# Out:
#         business_name                                       business_url  \
# 0  Nespresso Boutique  https://www.yelp.com/adredir?ad_business_id=YT...
# 1           Starbucks  https://www.yelp.com/adredir?ad_business_id=Nv...
# 2       A Baked Joint  https://www.yelp.com/biz/a-baked-joint-washing...
# 3            Zaytinya       https://www.yelp.com/biz/zaytinya-washington
# 4        Le Diplomate   https://www.yelp.com/biz/le-diplomate-washington
#
#    business_phone     business_address  business_rating business_review_count  \
# 0  (800) 562-1465       100 S Hayes St              4.0                    26
# 1           -5139  2225 Georgia Ave NW              3.0                    24
# 2  (202) 408-6985          430 K St NW              4.5                  1918
# 3  (202) 638-0800        701 9th St NW              4.0                  4687
# 4  (202) 332-3333      1601 14th St NW              4.5                  3607
#
#                          business_price_category business_neighborhood  \
# 0         Coffee & Tea, Coffee Roasteries, Cafes                   NaN
# 1               Breakfast & Brunch, Coffee & Tea                   NaN
# 2  $Coffee & Tea, Breakfast & Brunch, Sandwiches                   NaN
# 3                    $$$Greek, Turkish, Lebanese                   NaN
# 4      $$$Brasseries, French, Breakfast & Brunch          Logan Circle
#
#    business_index
# 0             NaN
# 1             NaN
# 2             1.0
# 3             2.0
# 4             3.0

# %%
# Print the shape of the data
PH_DC.shape
# Out:
# (6352, 9)

# %%
colnames = ['name','url','phone','address','rating','review_count','price_category','neighborhood','index']
PH_DC.columns = colnames
PH_DC.head()
# Out:
#                  name                                                url  \
# 0  Nespresso Boutique  https://www.yelp.com/adredir?ad_business_id=YT...
# 1           Starbucks  https://www.yelp.com/adredir?ad_business_id=Nv...
# 2       A Baked Joint  https://www.yelp.com/biz/a-baked-joint-washing...
# 3            Zaytinya       https://www.yelp.com/biz/zaytinya-washington
# 4        Le Diplomate   https://www.yelp.com/biz/le-diplomate-washington
#
#             phone              address  rating review_count  \
# 0  (800) 562-1465       100 S Hayes St     4.0           26
# 1           -5139  2225 Georgia Ave NW     3.0           24
# 2  (202) 408-6985          430 K St NW     4.5         1918
# 3  (202) 638-0800        701 9th St NW     4.0         4687
# 4  (202) 332-3333      1601 14th St NW     4.5         3607
#
#                                   price_category  neighborhood  index
# 0         Coffee & Tea, Coffee Roasteries, Cafes           NaN    NaN
# 1               Breakfast & Brunch, Coffee & Tea           NaN    NaN
# 2  $Coffee & Tea, Breakfast & Brunch, Sandwiches           NaN    1.0
# 3                    $$$Greek, Turkish, Lebanese           NaN    2.0
# 4      $$$Brasseries, French, Breakfast & Brunch  Logan Circle    3.0

# %%
# Drop sponsored businesses
PH_DC.dropna(subset=['index'],inplace=True)
PH_DC = PH_DC.drop('index',axis=1)
PH_DC.shape
# Out:
# (4854, 8)

# %%
# Drop duplicated businesses
PH_DC.drop_duplicates(subset='name',keep="first",inplace=True)
PH_DC.shape
# Out:
# (1753, 8)

# %%
# Split price_category into two columns
PH_DC[['price_range','category']] = PH_DC.price_category.str.rsplit("$",1,expand=True)
PH_DC = PH_DC.drop('price_category',axis=1)
PH_DC.head()
# Out:
#                    name                                                url  \
# 2         A Baked Joint  https://www.yelp.com/biz/a-baked-joint-washing...
# 3              Zaytinya       https://www.yelp.com/biz/zaytinya-washington
# 4          Le Diplomate   https://www.yelp.com/biz/le-diplomate-washington
# 5  Unconventional Diner  https://www.yelp.com/biz/unconventional-diner-...
# 6      Old Ebbitt Grill  https://www.yelp.com/biz/old-ebbitt-grill-wash...
#
#             phone          address  rating review_count  neighborhood  \
# 2  (202) 408-6985      430 K St NW     4.5         1918           NaN
# 3  (202) 638-0800    701 9th St NW     4.0         4687           NaN
# 4  (202) 332-3333  1601 14th St NW     4.5         3607  Logan Circle
# 5  (202) 847-0122   1207 9th St NW     4.5         1166          Shaw
# 6  (202) 347-4800   675 15th St NW     4.0         8513           NaN
#
#   price_range                                          category
# 2                  Coffee & Tea, Breakfast & Brunch, Sandwiches
# 3          $$                          Greek, Turkish, Lebanese
# 4          $$            Brasseries, French, Breakfast & Brunch
# 5           $                American (New), Breakfast & Brunch
# 6           $  Bars, American (Traditional), Breakfast & Brunch

# %%
# Save the indices of NaN in category
swap = PH_DC.index[PH_DC['category'].isna()]

# Fill NaN in category with price_range
PH_DC['category'] = PH_DC['category'].fillna(PH_DC['price_range'])

# Add back one $ to price_range
PH_DC['price_range'] = PH_DC['price_range']+'$'

# Replace missing values with NaN
PH_DC['price_range'].loc[swap] = np.nan

# Convert category into list of strings
PH_DC['category'] = PH_DC.category.str.split(", ",expand=False)

PH_DC.head()
# Out:
#                    name                                                url  \
# 2         A Baked Joint  https://www.yelp.com/biz/a-baked-joint-washing...
# 3              Zaytinya       https://www.yelp.com/biz/zaytinya-washington
# 4          Le Diplomate   https://www.yelp.com/biz/le-diplomate-washington
# 5  Unconventional Diner  https://www.yelp.com/biz/unconventional-diner-...
# 6      Old Ebbitt Grill  https://www.yelp.com/biz/old-ebbitt-grill-wash...
#
#             phone          address  rating review_count  neighborhood  \
# 2  (202) 408-6985      430 K St NW     4.5         1918           NaN
# 3  (202) 638-0800    701 9th St NW     4.0         4687           NaN
# 4  (202) 332-3333  1601 14th St NW     4.5         3607  Logan Circle
# 5  (202) 847-0122   1207 9th St NW     4.5         1166          Shaw
# 6  (202) 347-4800   675 15th St NW     4.0         8513           NaN
#
#   price_range                                           category
# 2           $     [Coffee & Tea, Breakfast & Brunch, Sandwiches]
# 3         $$$                         [Greek, Turkish, Lebanese]
# 4         $$$           [Brasseries, French, Breakfast & Brunch]
# 5          $$               [American (New), Breakfast & Brunch]
# 6          $$  [Bars, American (Traditional), Breakfast & Bru...

# %%
PH_DC.dtypes
# Out:
# name             object
# url              object
# phone            object
# address          object
# rating          float64
# review_count     object
# neighborhood     object
# price_range      object
# category         object
# dtype: object

# %%
# Convert review_count to int
PH_DC['review_count'] =  PH_DC['review_count'].apply(pd.to_numeric,errors='coerce')
PH_DC.dropna(subset=['review_count'],inplace=True)
PH_DC['review_count'] =  PH_DC['review_count'].astype(int)

# %%
# Convert price_range to float
PH_DC['price_range'] = PH_DC.price_range.replace('$$$$',4)
PH_DC['price_range'] = PH_DC.price_range.replace('$$$',3)
PH_DC['price_range'] = PH_DC.price_range.replace('$$',2)
PH_DC['price_range'] = PH_DC.price_range.replace('$',1)

# %%
PH_DC['name'] = PH_DC.name.str.replace('’',"'")
PH_DC['name'] = PH_DC.name.str.replace(' - Temp. CLOSED',"")
PH_DC['region'] = 'Washington DC'

# %%
PH_DC.dtypes
# Out:
# name             object
# url              object
# phone            object
# address          object
# rating          float64
# review_count      int64
# neighborhood     object
# price_range     float64
# category         object
# region           object
# dtype: object

# %%
PH_DC.shape
# Out:
# (1651, 10)

# %% [markdown]
# ## Merge PH_DC and DC_Wiki

# %%
# Read in the data
DC_Wiki = pd.read_csv("Data/Wikipedia/Wiki_DC.csv")
DC_Wiki.head()
# Out:
#                        Name Neighborhood/City              2017  \
# 0          Blue Duck Tavern          West End   1 Michelin star
# 1                    Bresca      Logan Circle               NaN
# 2                     Fiola      Penn Quarter   1 Michelin star
# 3                  Gravitas          Ivy City               NaN
# 4  Inn at Little Washington    Washington, VA  2 Michelin stars
#
#                2018              2019              2020
# 0   1 Michelin star   1 Michelin star               NaN
# 1               NaN   1 Michelin star   1 Michelin star
# 2   1 Michelin star   1 Michelin star   1 Michelin star
# 3               NaN               NaN   1 Michelin star
# 4  2 Michelin stars  3 Michelin stars  3 Michelin stars

# %%
list(DC_Wiki.columns)[1:-1]
# Out:
# ['Neighborhood/City', '2017', '2018', '2019']

# %%
DC_Wiki = DC_Wiki.drop(list(DC_Wiki.columns)[1:-1],axis=1)
DC_Wiki.dropna(subset=['2020'],inplace=True)
DC_Wiki.head()
# Out:
#                        Name              2020
# 1                    Bresca   1 Michelin star
# 2                     Fiola   1 Michelin star
# 3                  Gravitas   1 Michelin star
# 4  Inn at Little Washington  3 Michelin stars
# 5                   Kinship   1 Michelin star

# %%
# Anti merge
m = (pd
     .merge(left = PH_DC, 
            right = DC_Wiki, 
            how = 'outer', 
            left_on = "name", 
            right_on = "Name",
            indicator = True))
m.loc[m._merge=="right_only",:].drop(columns="_merge")
# Out:
#      name  url phone address  rating  review_count neighborhood  price_range  \
# 1651  NaN  NaN   NaN     NaN     NaN           NaN          NaN          NaN
# 1652  NaN  NaN   NaN     NaN     NaN           NaN          NaN          NaN
#
#      category region                      Name              2020
# 1651      NaN    NaN  Inn at Little Washington  3 Michelin stars
# 1652      NaN    NaN                   minibar  2 Michelin stars

# %%
# The Inn at Little Washington
DC_Wiki['Name'] = DC_Wiki.Name.replace('Inn at Little Washington','The Inn at Little Washington')

# minibar by José Andrés
DC_Wiki['Name'] = DC_Wiki.Name.replace('minibar','minibar by José Andrés')

# %%
DC_PW = (pd
         .merge(left = PH_DC,
                right = DC_Wiki,
                how = "left",
                left_on = "name",
                right_on = "Name")
         .drop("Name", axis = 1)
         .rename(columns = {"2020":"michelin_star"}))

# %%
DC_PW['michelin_star'] = DC_PW.michelin_star.fillna(0)
DC_PW['michelin_star'] = DC_PW.michelin_star.replace('1 Michelin star',1)
DC_PW['michelin_star'] = DC_PW.michelin_star.replace('2 Michelin stars',2)
DC_PW['michelin_star'] = DC_PW.michelin_star.replace('3 Michelin stars',3)

DC_PW.head()
# Out:
#                    name                                                url  \
# 0         A Baked Joint  https://www.yelp.com/biz/a-baked-joint-washing...
# 1              Zaytinya       https://www.yelp.com/biz/zaytinya-washington
# 2          Le Diplomate   https://www.yelp.com/biz/le-diplomate-washington
# 3  Unconventional Diner  https://www.yelp.com/biz/unconventional-diner-...
# 4      Old Ebbitt Grill  https://www.yelp.com/biz/old-ebbitt-grill-wash...
#
#             phone          address  rating  review_count  neighborhood  \
# 0  (202) 408-6985      430 K St NW     4.5          1918           NaN
# 1  (202) 638-0800    701 9th St NW     4.0          4687           NaN
# 2  (202) 332-3333  1601 14th St NW     4.5          3607  Logan Circle
# 3  (202) 847-0122   1207 9th St NW     4.5          1166          Shaw
# 4  (202) 347-4800   675 15th St NW     4.0          8513           NaN
#
#    price_range                                           category  \
# 0          1.0     [Coffee & Tea, Breakfast & Brunch, Sandwiches]
# 1          3.0                         [Greek, Turkish, Lebanese]
# 2          3.0           [Brasseries, French, Breakfast & Brunch]
# 3          2.0               [American (New), Breakfast & Brunch]
# 4          2.0  [Bars, American (Traditional), Breakfast & Bru...
#
#           region  michelin_star
# 0  Washington DC              0
# 1  Washington DC              0
# 2  Washington DC              0
# 3  Washington DC              0
# 4  Washington DC              0

# %%
DC_Wiki.shape
# Out:
# (18, 2)

# %%
DC_PW.query('michelin_star != 0').shape
# Out:
# (18, 11)

# %% [markdown]
# ## Merge DC_PW and Michelin

# %%
# Read in the data
Michelin = pd.read_csv("Data/Michelin/Michelin.csv")
DC_MG = Michelin.loc[Michelin['region'] == "Washington DC"].drop(['region','url'],axis=1)
DC_MG['name'] = DC_MG.name.str.replace('’',"'")
DC_MG.head()
# Out:
#               name  michelin_guide
# 0          Himitsu               1
# 1        BlackSalt               1
# 2             Tico               1
# 3  Ottoman Taverna               1
# 4             1789               1

# %%
DC_PW['name'] = DC_PW['name'].str.lower()
DC_MG['name'] = DC_MG['name'].str.lower()

# %%
# Anti merge
m = (pd
     .merge(left = DC_PW, 
            right = DC_MG, 
            how = 'outer', 
            on = "name",  
            indicator = True))
m.loc[m._merge=="right_only",:].drop(columns="_merge")
# Out:
#                           name  url phone address  rating  review_count  \
# 1651                   himitsu  NaN   NaN     NaN     NaN           NaN
# 1652                      tico  NaN   NaN     NaN     NaN           NaN
# 1653                      1789  NaN   NaN     NaN     NaN           NaN
# 1654               all purpose  NaN   NaN     NaN     NaN           NaN
# 1655                  marcel's  NaN   NaN     NaN     NaN           NaN
# 1656                astoria dc  NaN   NaN     NaN     NaN           NaN
# 1657                  zenebech  NaN   NaN     NaN     NaN           NaN
# 1658                    maydān  NaN   NaN     NaN     NaN           NaN
# 1659                       das  NaN   NaN     NaN     NaN           NaN
# 1660                     royal  NaN   NaN     NaN     NaN           NaN
# 1661               bombay club  NaN   NaN     NaN     NaN           NaN
# 1662                  hanumanh  NaN   NaN     NaN     NaN           NaN
# 1663                  sfoglina  NaN   NaN     NaN     NaN           NaN
# 1664                 mirabelle  NaN   NaN     NaN     NaN           NaN
# 1665                     tosca  NaN   NaN     NaN     NaN           NaN
# 1666                       ana  NaN   NaN     NaN     NaN           NaN
# 1667      pineapple and pearls  NaN   NaN     NaN     NaN           NaN
# 1668                  chercher  NaN   NaN     NaN     NaN           NaN
# 1669                  millie's  NaN   NaN     NaN     NaN           NaN
# 1670                    sonoma  NaN   NaN     NaN     NaN           NaN
# 1671              the pembroke  NaN   NaN     NaN     NaN           NaN
# 1672               san lorenzo  NaN   NaN     NaN     NaN           NaN
# 1673                      anxo  NaN   NaN     NaN     NaN           NaN
# 1674                   minibar  NaN   NaN     NaN     NaN           NaN
# 1675         hank's oyster bar  NaN   NaN     NaN     NaN           NaN
# 1676           timber pizza co  NaN   NaN     NaN     NaN           NaN
# 1677  joselito casa de comidas  NaN   NaN     NaN     NaN           NaN
# 1678            spoken english  NaN   NaN     NaN     NaN           NaN
# 1679                     keren  NaN   NaN     NaN     NaN           NaN
# 1680              american son  NaN   NaN     NaN     NaN           NaN
# 1681                   bidwell  NaN   NaN     NaN     NaN           NaN
# 1682                 succotash  NaN   NaN     NaN     NaN           NaN
#
#      neighborhood  price_range category region  michelin_star  michelin_guide
# 1651          NaN          NaN      NaN    NaN            NaN             1.0
# 1652          NaN          NaN      NaN    NaN            NaN             1.0
# 1653          NaN          NaN      NaN    NaN            NaN             1.0
# 1654          NaN          NaN      NaN    NaN            NaN             1.0
# 1655          NaN          NaN      NaN    NaN            NaN             1.0
# 1656          NaN          NaN      NaN    NaN            NaN             1.0
# 1657          NaN          NaN      NaN    NaN            NaN             1.0
# 1658          NaN          NaN      NaN    NaN            NaN             1.0
# 1659          NaN          NaN      NaN    NaN            NaN             1.0
# 1660          NaN          NaN      NaN    NaN            NaN             1.0
# 1661          NaN          NaN      NaN    NaN            NaN             1.0
# 1662          NaN          NaN      NaN    NaN            NaN             1.0
# 1663          NaN          NaN      NaN    NaN            NaN             1.0
# 1664          NaN          NaN      NaN    NaN            NaN             1.0
# 1665          NaN          NaN      NaN    NaN            NaN             1.0
# 1666          NaN          NaN      NaN    NaN            NaN             1.0
# 1667          NaN          NaN      NaN    NaN            NaN             1.0
# 1668          NaN          NaN      NaN    NaN            NaN             1.0
# 1669          NaN          NaN      NaN    NaN            NaN             1.0
# 1670          NaN          NaN      NaN    NaN            NaN             1.0
# 1671          NaN          NaN      NaN    NaN            NaN             1.0
# 1672          NaN          NaN      NaN    NaN            NaN             1.0
# 1673          NaN          NaN      NaN    NaN            NaN             1.0
# 1674          NaN          NaN      NaN    NaN            NaN             1.0
# 1675          NaN          NaN      NaN    NaN            NaN             1.0
# 1676          NaN          NaN      NaN    NaN            NaN             1.0
# 1677          NaN          NaN      NaN    NaN            NaN             1.0
# 1678          NaN          NaN      NaN    NaN            NaN             1.0
# 1679          NaN          NaN      NaN    NaN            NaN             1.0
# 1680          NaN          NaN      NaN    NaN            NaN             1.0
# 1681          NaN          NaN      NaN    NaN            NaN             1.0
# 1682          NaN          NaN      NaN    NaN            NaN             1.0

# %%
# minibar by josé andrés
DC_MG['name'] = DC_MG.name.replace('minibar','minibar by josé andrés')

# pineapple and pearls
DC_PW['name'] = DC_PW.name.replace('pineapple & pearls','pineapple and pearls')

# Tico
DC_PW['name'] = DC_PW.name.replace('tico dc','tico')

# 1789
DC_MG['name'] = DC_MG.name.replace('1789','1789 restaurant')

# All-Purpose Shaw
DC_MG['name'] = DC_MG.name.replace('all purpose','all-purpose shaw')

# Marcel's by Robert Wiedmaier
DC_MG['name'] = DC_MG.name.replace("marcel's","marcel's by robert wiedmaier")

# Zenebech Restaurant
DC_MG['name'] = DC_MG.name.replace("zenebech","zenebech restaurant")

# Maydan
DC_MG['name'] = DC_MG.name.replace("maydān","maydan")

# Das Ethiopian
DC_MG['name'] = DC_MG.name.replace("das","das ethiopian")

# The Royal
DC_MG['name'] = DC_MG.name.replace("royal","the royal")

# The Bombay Club
DC_MG['name'] = DC_MG.name.replace("bombay club","the bombay club")

# Sfoglina Van Ness
DC_MG['name'] = DC_MG.name.replace("sfoglina","sfoglina van ness")

# chercher ethiopian restaurant & mart
DC_MG['name'] = DC_MG.name.replace("chercher","chercher ethiopian restaurant & mart")

# millie's spring valley
DC_MG['name'] = DC_MG.name.replace("millie's","millie's spring valley")

# sonoma restaurant and wine bar
DC_MG['name'] = DC_MG.name.replace("sonoma","sonoma restaurant and wine bar")

# anxo cidery & pintxos bar
DC_MG['name'] = DC_MG.name.replace("anxo","anxo cidery & pintxos bar")

# hank's oyster bar - dupont circle
DC_MG['name'] = DC_MG.name.replace("hank's oyster bar","hank's oyster bar - dupont circle")

# timber pizza company
DC_MG['name'] = DC_MG.name.replace("timber pizza co","timber pizza company")

# joselito
DC_MG['name'] = DC_MG.name.replace("joselito casa de comidas","joselito")

# keren restaurant
DC_MG['name'] = DC_MG.name.replace("keren","keren restaurant")

# bidwell restaurant
DC_MG['name'] = DC_MG.name.replace("bidwell","bidwell restaurant")

# %%
# DC_PW[DC_PW.name.str.contains('bidwell')]

# %%
# Anti merge
m = (pd
     .merge(left = DC_PW, 
            right = DC_MG, 
            how = 'outer', 
            on = "name",  
            indicator = True))
m.loc[m._merge=="right_only",:].drop(columns="_merge")
# Out:
#                 name  url phone address  rating  review_count neighborhood  \
# 1651         himitsu  NaN   NaN     NaN     NaN           NaN          NaN
# 1652      astoria dc  NaN   NaN     NaN     NaN           NaN          NaN
# 1653        hanumanh  NaN   NaN     NaN     NaN           NaN          NaN
# 1654       mirabelle  NaN   NaN     NaN     NaN           NaN          NaN
# 1655           tosca  NaN   NaN     NaN     NaN           NaN          NaN
# 1656             ana  NaN   NaN     NaN     NaN           NaN          NaN
# 1657    the pembroke  NaN   NaN     NaN     NaN           NaN          NaN
# 1658     san lorenzo  NaN   NaN     NaN     NaN           NaN          NaN
# 1659  spoken english  NaN   NaN     NaN     NaN           NaN          NaN
# 1660    american son  NaN   NaN     NaN     NaN           NaN          NaN
# 1661       succotash  NaN   NaN     NaN     NaN           NaN          NaN
#
#       price_range category region  michelin_star  michelin_guide
# 1651          NaN      NaN    NaN            NaN             1.0
# 1652          NaN      NaN    NaN            NaN             1.0
# 1653          NaN      NaN    NaN            NaN             1.0
# 1654          NaN      NaN    NaN            NaN             1.0
# 1655          NaN      NaN    NaN            NaN             1.0
# 1656          NaN      NaN    NaN            NaN             1.0
# 1657          NaN      NaN    NaN            NaN             1.0
# 1658          NaN      NaN    NaN            NaN             1.0
# 1659          NaN      NaN    NaN            NaN             1.0
# 1660          NaN      NaN    NaN            NaN             1.0
# 1661          NaN      NaN    NaN            NaN             1.0

# %%
DC = (pd
      .merge(left = DC_PW,
             right = DC_MG,
             how = "left",
             on = "name",))

# Fill NaN in michelin_guide with 0
DC['michelin_guide'] = DC['michelin_guide'].fillna(0)
DC['michelin_guide'] = DC['michelin_guide'].astype(int)

DC.head()
# Out:
#                    name                                                url  \
# 0         a baked joint  https://www.yelp.com/biz/a-baked-joint-washing...
# 1              zaytinya       https://www.yelp.com/biz/zaytinya-washington
# 2          le diplomate   https://www.yelp.com/biz/le-diplomate-washington
# 3  unconventional diner  https://www.yelp.com/biz/unconventional-diner-...
# 4      old ebbitt grill  https://www.yelp.com/biz/old-ebbitt-grill-wash...
#
#             phone          address  rating  review_count  neighborhood  \
# 0  (202) 408-6985      430 K St NW     4.5          1918           NaN
# 1  (202) 638-0800    701 9th St NW     4.0          4687           NaN
# 2  (202) 332-3333  1601 14th St NW     4.5          3607  Logan Circle
# 3  (202) 847-0122   1207 9th St NW     4.5          1166          Shaw
# 4  (202) 347-4800   675 15th St NW     4.0          8513           NaN
#
#    price_range                                           category  \
# 0          1.0     [Coffee & Tea, Breakfast & Brunch, Sandwiches]
# 1          3.0                         [Greek, Turkish, Lebanese]
# 2          3.0           [Brasseries, French, Breakfast & Brunch]
# 3          2.0               [American (New), Breakfast & Brunch]
# 4          2.0  [Bars, American (Traditional), Breakfast & Bru...
#
#           region  michelin_star  michelin_guide
# 0  Washington DC              0               0
# 1  Washington DC              0               1
# 2  Washington DC              0               0
# 3  Washington DC              0               1
# 4  Washington DC              0               0

# %%
DC_MG.shape
# Out:
# (116, 2)

# %%
DC.query('michelin_guide == 1').shape
# Out:
# (105, 12)

# %%
# Export to a CSV file
DC.to_csv('Data/DC.csv',index=False)

# %%
# Build a function to clean ParseHub data
def PH_clean(df,region="New York City"):
    """
    This is a function that takes ParseHub data as an input and output a cleaned version.

    Args:
        df (DataFrame): raw ParseHub dataframe.
        region (str): region name.

    Returns:
        DataFrame: cleaned ParseHub dataframe.
    """
    colnames = ['name','url','phone','address','rating','review_count','price_category','neighborhood','index']
    df.columns = colnames
    
    # Drop sponsored businesses
    df.dropna(subset=['index'],inplace=True)
    df = df.drop('index',axis=1)

    # Drop duplicated businesses
    df.drop_duplicates(subset='name',keep="first",inplace=True)
    
    # Split price_category into two columns
    df[['price_range','category']] = df.price_category.str.rsplit("$",1,expand=True)
    df = df.drop('price_category',axis=1)

    # Save the indices of NaN in category
    swap = df.index[df['category'].isna()]

    # Fill NaN in category with price_range
    df['category'] = df['category'].fillna(df['price_range'])

    # Add back one $ to price_range
    df['price_range'] = df['price_range']+'$'

    # Replace missing values with NaN
    df['price_range'].loc[swap] = np.nan

    # Convert category into list of strings
    df['category'] = df.category.str.split(", ",expand=False)
    
    # Convert review_count to int
    df['review_count'] = df['review_count'].apply(pd.to_numeric,errors='coerce')
    df.dropna(subset=['review_count'],inplace=True)
    df['review_count'] = df['review_count'].astype(int)
    
    # Convert price_range to float
    df['price_range'] = df.price_range.replace('$$$$',4)
    df['price_range'] = df.price_range.replace('$$$',3)
    df['price_range'] = df.price_range.replace('$$',2)
    df['price_range'] = df.price_range.replace('$',1)
    
    df['name'] = df.name.str.replace('’',"'")
    df['name'] = df.name.str.replace(' - Temp. CLOSED',"")
    df['name'] = df.name.str.replace(' - CLOSED',"")
    df['name'] = df['name'].str.lower()
    df['region'] = region

    # Return data
    return df

# %% [markdown]
# ## Clean PH_NY

# %%
# Read in the data
PH_NY = pd.read_csv("Data/ParseHub/PH_NY.csv")

# Print the shape of the data
PH_NY.shape
# Out:
# (8201, 9)

# %%
PH_NY = PH_clean(PH_NY,region="New York City")
PH_NY.shape
# Out:
# (4471, 10)

# %% [markdown]
# ## Merge PH_NY and NY_Wiki

# %%
# Read in the data
NY_Wiki = pd.read_csv("Data/Wikipedia/Wiki_NY.csv")
NY_Wiki = NY_Wiki.drop(list(NY_Wiki.columns)[1:-1],axis=1)
NY_Wiki.dropna(subset=['2020'],inplace=True)
NY_Wiki['Name'] = NY_Wiki['Name'].str.lower()

# %%
# Anti merge
m = (pd
     .merge(left = PH_NY, 
            right = NY_Wiki, 
            how = 'outer', 
            left_on = "name", 
            right_on = "Name",
            indicator = True))
m.loc[m._merge=="right_only",:].drop(columns="_merge")
# Out:
#      name  url phone address rating  review_count neighborhood  price_range  \
# 4471  NaN  NaN   NaN     NaN    NaN           NaN          NaN          NaN
# 4472  NaN  NaN   NaN     NaN    NaN           NaN          NaN          NaN
# 4473  NaN  NaN   NaN     NaN    NaN           NaN          NaN          NaN
# 4474  NaN  NaN   NaN     NaN    NaN           NaN          NaN          NaN
# 4475  NaN  NaN   NaN     NaN    NaN           NaN          NaN          NaN
# 4476  NaN  NaN   NaN     NaN    NaN           NaN          NaN          NaN
# 4477  NaN  NaN   NaN     NaN    NaN           NaN          NaN          NaN
# 4478  NaN  NaN   NaN     NaN    NaN           NaN          NaN          NaN
# 4479  NaN  NaN   NaN     NaN    NaN           NaN          NaN          NaN
# 4480  NaN  NaN   NaN     NaN    NaN           NaN          NaN          NaN
# 4481  NaN  NaN   NaN     NaN    NaN           NaN          NaN          NaN
#
#      category region                      Name              2020
# 4471      NaN    NaN                  bar uchū   1 Michelin star
# 4472      NaN    NaN                     benno   1 Michelin star
# 4473      NaN    NaN  blue hill at stone barns  2 Michelin stars
# 4474      NaN    NaN                 the finch   1 Michelin star
# 4475      NaN    NaN      gotham bar and grill   1 Michelin star
# 4476      NaN    NaN          ichimura at uchū  2 Michelin stars
# 4477      NaN    NaN                 the nomad   1 Michelin star
# 4478      NaN    NaN   peter luger steak house   1 Michelin star
# 4479      NaN    NaN                   satsuki   1 Michelin star
# 4480      NaN    NaN                     ukiyo   1 Michelin star
# 4481      NaN    NaN                    wallsé   1 Michelin star

# %%
# blue hill
NY_Wiki['Name'] = NY_Wiki.Name.replace('blue hill at stone barns','blue hill')

# uchu
NY_Wiki['Name'] = NY_Wiki.Name.replace('ichimura at uchū','uchu')

# uchu
NY_Wiki['Name'] = NY_Wiki.Name.replace('ichimura at uchū','uchu')

# benno restaurant
NY_Wiki['Name'] = NY_Wiki.Name.replace('benno','benno restaurant')

# peter luger
NY_Wiki['Name'] = NY_Wiki.Name.replace('peter luger steak house','peter luger')

# wallse
NY_Wiki['Name'] = NY_Wiki.Name.replace('wallsé','wallse')

# the nomad restaurant
NY_Wiki['Name'] = NY_Wiki.Name.replace('the nomad','the nomad restaurant')

# %%
# PH_NY[PH_NY.name.str.contains('amane')]

# %%
# Anti merge
m = (pd
     .merge(left = PH_NY, 
            right = NY_Wiki, 
            how = 'outer', 
            left_on = "name", 
            right_on = "Name",
            indicator = True))
m.loc[m._merge=="right_only",:].drop(columns="_merge")
# Out:
#      name  url phone address rating  review_count neighborhood  price_range  \
# 4472  NaN  NaN   NaN     NaN    NaN           NaN          NaN          NaN
# 4473  NaN  NaN   NaN     NaN    NaN           NaN          NaN          NaN
# 4474  NaN  NaN   NaN     NaN    NaN           NaN          NaN          NaN
# 4475  NaN  NaN   NaN     NaN    NaN           NaN          NaN          NaN
# 4476  NaN  NaN   NaN     NaN    NaN           NaN          NaN          NaN
#
#      category region                  Name             2020
# 4472      NaN    NaN              bar uchū  1 Michelin star
# 4473      NaN    NaN             the finch  1 Michelin star
# 4474      NaN    NaN  gotham bar and grill  1 Michelin star
# 4475      NaN    NaN               satsuki  1 Michelin star
# 4476      NaN    NaN                 ukiyo  1 Michelin star

# %%
NY_PW = (pd
         .merge(left = PH_NY,
                right = NY_Wiki,
                how = "left",
                left_on = "name",
                right_on = "Name")
         .drop("Name", axis = 1)
         .rename(columns = {"2020":"michelin_star"}))

# %%
NY_PW['michelin_star'] = NY_PW.michelin_star.fillna(0)
NY_PW['michelin_star'] = NY_PW.michelin_star.replace('1 Michelin star',1)
NY_PW['michelin_star'] = NY_PW.michelin_star.replace('2 Michelin stars',2)
NY_PW['michelin_star'] = NY_PW.michelin_star.replace('3 Michelin stars',3)

# %%
NY_Wiki.shape
# Out:
# (75, 2)

# %%
NY_PW.query('michelin_star != 0').shape
# Out:
# (70, 11)

# %% [markdown]
# ## Merge NY_PW and Michelin

# %%
NY_MG = Michelin.loc[Michelin['region'] == "New York City"].drop(['region','url'],axis=1)
NY_MG['name'] = NY_MG.name.str.replace('’',"'")
NY_MG['name'] = NY_MG['name'].str.lower()
NY_MG.shape
# Out:
# (513, 2)

# %%
# Anti merge
m = (pd
     .merge(left = NY_PW, 
            right = NY_MG, 
            how = 'outer', 
            on = "name",  
            indicator = True))
m.loc[m._merge=="right_only",:].drop(columns="_merge")
# Out:
#                              name  url phone address rating  review_count  \
# 4472                maison harlem  NaN   NaN     NaN    NaN           NaN
# 4473                 málà project  NaN   NaN     NaN    NaN           NaN
# 4474                       coarse  NaN   NaN     NaN    NaN           NaN
# 4475      saint julivert fisherie  NaN   NaN     NaN    NaN           NaN
# 4476                       lamalo  NaN   NaN     NaN    NaN           NaN
# ...                           ...  ...   ...     ...    ...           ...
# 4804  da franco & tony ristorante  NaN   NaN     NaN    NaN           NaN
# 4805                pinch chinese  NaN   NaN     NaN    NaN           NaN
# 4806                enoteca maria  NaN   NaN     NaN    NaN           NaN
# 4807                       i sodi  NaN   NaN     NaN    NaN           NaN
# 4808           vinegar hill house  NaN   NaN     NaN    NaN           NaN
#
#      neighborhood  price_range category region  michelin_star  michelin_guide
# 4472          NaN          NaN      NaN    NaN            NaN             1.0
# 4473          NaN          NaN      NaN    NaN            NaN             1.0
# 4474          NaN          NaN      NaN    NaN            NaN             1.0
# 4475          NaN          NaN      NaN    NaN            NaN             1.0
# 4476          NaN          NaN      NaN    NaN            NaN             1.0
# ...           ...          ...      ...    ...            ...             ...
# 4804          NaN          NaN      NaN    NaN            NaN             1.0
# 4805          NaN          NaN      NaN    NaN            NaN             1.0
# 4806          NaN          NaN      NaN    NaN            NaN             1.0
# 4807          NaN          NaN      NaN    NaN            NaN             1.0
# 4808          NaN          NaN      NaN    NaN            NaN             1.0
#
# [337 rows x 12 columns]

# %%
NY = (pd
      .merge(left = NY_PW,
             right = NY_MG,
             how = "left",
             on = "name",))

# %%
# Fill NaN in michelin_guide with 0
NY['michelin_guide'] = NY['michelin_guide'].fillna(0)
NY['michelin_guide'] = NY['michelin_guide'].astype(int)

star = NY[NY.michelin_star != 0].index
NY['michelin_guide'].loc[star] = 1

# %%
# Export to a CSV file
NY.to_csv('Data/NY.csv',index=False)

# %% [markdown]
# ## Clean PH_CH

# %%
# Read in the data
PH_CH = pd.read_csv("Data/ParseHub/PH_CH.csv")

# Print the shape of the data
PH_CH.shape
# Out:
# (5172, 9)

# %%
PH_CH = PH_clean(PH_CH,region="Chicago")
PH_CH.shape
# Out:
# (2565, 10)

# %% [markdown]
# ## Merge PH_NY and NY_Wiki

# %%
# Read in the data
CH_Wiki = pd.read_csv("Data/Wikipedia/Wiki_Chicago.csv")
CH_Wiki = CH_Wiki.drop(list(CH_Wiki.columns)[1:-1],axis=1)
CH_Wiki.dropna(subset=['2020'],inplace=True)
CH_Wiki['Name'] = CH_Wiki['Name'].str.lower()

# %%
# Anti merge
m = (pd
     .merge(left = PH_CH, 
            right = CH_Wiki, 
            how = 'outer', 
            left_on = "name", 
            right_on = "Name",
            indicator = True))
m.loc[m._merge=="right_only",:].drop(columns="_merge")
# Out:
#      name  url phone address  rating  review_count neighborhood  price_range  \
# 2565  NaN  NaN   NaN     NaN     NaN           NaN          NaN          NaN
# 2566  NaN  NaN   NaN     NaN     NaN           NaN          NaN          NaN
#
#      category region       Name             2020
# 2565      NaN    NaN  elizabeth  1 Michelin star
# 2566      NaN    NaN      yūgen  1 Michelin star

# %%
# yugen
CH_Wiki['Name'] = CH_Wiki.Name.replace('yūgen','yugen')

# elizabeth restaurant
CH_Wiki['Name'] = CH_Wiki.Name.replace('elizabeth','elizabeth restaurant')

# %%
# PH_CH[PH_CH.name.str.contains('elske')]

# %%
CH_PW = (pd
         .merge(left = PH_CH,
                right = CH_Wiki,
                how = "left",
                left_on = "name",
                right_on = "Name")
         .drop("Name", axis = 1)
         .rename(columns = {"2020":"michelin_star"}))

# %%
CH_PW['michelin_star'] = CH_PW.michelin_star.fillna(0)
CH_PW['michelin_star'] = CH_PW.michelin_star.replace('1 Michelin star',1)
CH_PW['michelin_star'] = CH_PW.michelin_star.replace('2 Michelin stars',2)
CH_PW['michelin_star'] = CH_PW.michelin_star.replace('3 Michelin stars',3)

# %%
CH_Wiki.shape
# Out:
# (25, 2)

# %%
CH_PW.query('michelin_star != 0').shape
# Out:
# (25, 11)

# %% [markdown]
# ## Merge CH_PW and Michelin

# %%
CH_MG = Michelin.loc[Michelin['region'] == "Chicago"].drop(['region','url'],axis=1)
CH_MG['name'] = CH_MG.name.str.replace('’',"'")
CH_MG['name'] = CH_MG['name'].str.lower()
CH_MG.shape
# Out:
# (176, 2)

# %%
# Anti merge
m = (pd
     .merge(left = CH_PW, 
            right = CH_MG, 
            how = 'outer', 
            on = "name",  
            indicator = True))
m.loc[m._merge=="right_only",:].drop(columns="_merge")
# Out:
#                         name  url phone address  rating  review_count  \
# 2565                  pelago  NaN   NaN     NaN     NaN           NaN
# 2566                  virtue  NaN   NaN     NaN     NaN           NaN
# 2567                   kikkō  NaN   NaN     NaN     NaN           NaN
# 2568                  demera  NaN   NaN     NaN     NaN           NaN
# 2569             staropolska  NaN   NaN     NaN     NaN           NaN
# ...                      ...  ...   ...     ...     ...           ...
# 2621                    mfk.  NaN   NaN     NaN     NaN           NaN
# 2622           sol de mexico  NaN   NaN     NaN     NaN           NaN
# 2623             the rosebud  NaN   NaN     NaN     NaN           NaN
# 2624  dusek's (board & beer)  NaN   NaN     NaN     NaN           NaN
# 2625               ghin khao  NaN   NaN     NaN     NaN           NaN
#
#      neighborhood  price_range category region  michelin_star  michelin_guide
# 2565          NaN          NaN      NaN    NaN            NaN             1.0
# 2566          NaN          NaN      NaN    NaN            NaN             1.0
# 2567          NaN          NaN      NaN    NaN            NaN             1.0
# 2568          NaN          NaN      NaN    NaN            NaN             1.0
# 2569          NaN          NaN      NaN    NaN            NaN             1.0
# ...           ...          ...      ...    ...            ...             ...
# 2621          NaN          NaN      NaN    NaN            NaN             1.0
# 2622          NaN          NaN      NaN    NaN            NaN             1.0
# 2623          NaN          NaN      NaN    NaN            NaN             1.0
# 2624          NaN          NaN      NaN    NaN            NaN             1.0
# 2625          NaN          NaN      NaN    NaN            NaN             1.0
#
# [61 rows x 12 columns]

# %%
# yugen
CH_MG['name'] = CH_MG.name.replace('yūgen','yugen')

# elizabeth restaurant
CH_MG['name'] = CH_MG.name.replace('elizabeth','elizabeth restaurant')

# pelago ristorante
CH_MG['name'] = CH_MG.name.replace('pelago','pelago ristorante')

# dolo restaurant and bar
CH_MG['name'] = CH_MG.name.replace('dolo','dolo restaurant and bar')

# southport grocery & cafe
CH_MG['name'] = CH_MG.name.replace('southport grocery','southport grocery & cafe')

# mccb chicago 时尚食谱
CH_PW['name'] = CH_PW.name.replace('mccb chicago 时尚食谱','mccb')

# virtue restaurant
CH_MG['name'] = CH_MG.name.replace('virtue','virtue restaurant')

# haisous vietnamese kitchen
CH_MG['name'] = CH_MG.name.replace('haisous','haisous vietnamese kitchen')

# gibsons italia
CH_MG['name'] = CH_MG.name.replace("gibson's italia",'gibsons italia')

# dusek's board & beer
CH_MG['name'] = CH_MG.name.replace("dusek's (board & beer)","dusek's board & beer")

# beatnik west town
CH_MG['name'] = CH_MG.name.replace("beatnik","beatnik west town")

# mi tocaya antojeria
CH_MG['name'] = CH_MG.name.replace("mi tocaya","mi tocaya antojeria")

# %%
# CH_PW[CH_PW.name.str.contains('tocaya')]

# %%
CH = (pd
      .merge(left = CH_PW,
             right = CH_MG,
             how = "left",
             on = "name",))

# %%
# Fill NaN in michelin_guide with 0
CH['michelin_guide'] = CH['michelin_guide'].fillna(0)
CH['michelin_guide'] = CH['michelin_guide'].astype(int)

star = CH[CH.michelin_star != 0].index
CH['michelin_guide'].loc[star] = 1

# %%
# Export to a CSV file
CH.to_csv('Data/CH.csv',index=False)

# %% [markdown]
# ## Clean PH_SF

# %%
# Read in the data
PH_SF = pd.read_csv("Data/ParseHub/PH_SF.csv")

# Print the shape of the data
PH_SF.shape
# Out:
# (3926, 9)

# %%
PH_SF = PH_clean(PH_SF,region="California")
PH_SF.shape
# Out:
# (1901, 10)

# %% [markdown]
# ## Merge PH_SF and SF_Wiki

# %%
# Read in the data
SF_Wiki = pd.read_csv("Data/Wikipedia/Wiki_SF.csv")
SF_Wiki = SF_Wiki.drop('City/Neighborhood',axis=1)
SF_Wiki['Name'] = SF_Wiki['Name'].str.lower()
SF_Wiki
# Out:
#                            Name              2019
# 0                    acquerello  2 Michelin stars
# 1                    al's place   1 Michelin star
# 2                        angler   1 Michelin star
# 3             auberge du soleil   1 Michelin star
# 4                     aubergine   1 Michelin star
# ..                          ...               ...
# 57                 the progress   1 Michelin star
# 58  the restaurant at meadowood  3 Michelin stars
# 59              the village pub   1 Michelin star
# 60                         wako   1 Michelin star
# 61                     wakuriya   1 Michelin star
#
# [62 rows x 2 columns]

# %%
# Anti merge
m = (pd
     .merge(left = PH_SF, 
            right = SF_Wiki, 
            how = 'outer', 
            left_on = "name", 
            right_on = "Name",
            indicator = True))
m.loc[m._merge=="right_only",:].drop(columns="_merge")
# Out:
#      name  url phone address  rating  review_count neighborhood  price_range  \
# 1901  NaN  NaN   NaN     NaN     NaN           NaN          NaN          NaN
# 1902  NaN  NaN   NaN     NaN     NaN           NaN          NaN          NaN
# 1903  NaN  NaN   NaN     NaN     NaN           NaN          NaN          NaN
# 1904  NaN  NaN   NaN     NaN     NaN           NaN          NaN          NaN
# 1905  NaN  NaN   NaN     NaN     NaN           NaN          NaN          NaN
# 1906  NaN  NaN   NaN     NaN     NaN           NaN          NaN          NaN
# 1907  NaN  NaN   NaN     NaN     NaN           NaN          NaN          NaN
# 1908  NaN  NaN   NaN     NaN     NaN           NaN          NaN          NaN
# 1909  NaN  NaN   NaN     NaN     NaN           NaN          NaN          NaN
# 1910  NaN  NaN   NaN     NaN     NaN           NaN          NaN          NaN
# 1911  NaN  NaN   NaN     NaN     NaN           NaN          NaN          NaN
# 1912  NaN  NaN   NaN     NaN     NaN           NaN          NaN          NaN
# 1913  NaN  NaN   NaN     NaN     NaN           NaN          NaN          NaN
# 1914  NaN  NaN   NaN     NaN     NaN           NaN          NaN          NaN
# 1915  NaN  NaN   NaN     NaN     NaN           NaN          NaN          NaN
# 1916  NaN  NaN   NaN     NaN     NaN           NaN          NaN          NaN
# 1917  NaN  NaN   NaN     NaN     NaN           NaN          NaN          NaN
# 1918  NaN  NaN   NaN     NaN     NaN           NaN          NaN          NaN
# 1919  NaN  NaN   NaN     NaN     NaN           NaN          NaN          NaN
# 1920  NaN  NaN   NaN     NaN     NaN           NaN          NaN          NaN
# 1921  NaN  NaN   NaN     NaN     NaN           NaN          NaN          NaN
# 1922  NaN  NaN   NaN     NaN     NaN           NaN          NaN          NaN
# 1923  NaN  NaN   NaN     NaN     NaN           NaN          NaN          NaN
# 1924  NaN  NaN   NaN     NaN     NaN           NaN          NaN          NaN
# 1925  NaN  NaN   NaN     NaN     NaN           NaN          NaN          NaN
# 1926  NaN  NaN   NaN     NaN     NaN           NaN          NaN          NaN
# 1927  NaN  NaN   NaN     NaN     NaN           NaN          NaN          NaN
# 1928  NaN  NaN   NaN     NaN     NaN           NaN          NaN          NaN
# 1929  NaN  NaN   NaN     NaN     NaN           NaN          NaN          NaN
# 1930  NaN  NaN   NaN     NaN     NaN           NaN          NaN          NaN
#
#      category region                         Name              2019
# 1901      NaN    NaN            auberge du soleil   1 Michelin star
# 1902      NaN    NaN                    aubergine   1 Michelin star
# 1903      NaN    NaN                        baumé  2 Michelin stars
# 1904      NaN    NaN                      bouchon   1 Michelin star
# 1905      NaN    NaN                      chez tj   1 Michelin star
# 1906      NaN    NaN                 commonwealth   1 Michelin star
# 1907      NaN    NaN   farmhouse inn & restaurant   1 Michelin star
# 1908      NaN    NaN                 harbor house   1 Michelin star
# 1909      NaN    NaN                        kenzo   1 Michelin star
# 1910      NaN    NaN                     kin khao   1 Michelin star
# 1911      NaN    NaN                        kinjo   1 Michelin star
# 1912      NaN    NaN                     la toque   1 Michelin star
# 1913      NaN    NaN                       madcap   1 Michelin star
# 1914      NaN    NaN                       madera   1 Michelin star
# 1915      NaN    NaN                madrona manor   1 Michelin star
# 1916      NaN    NaN                      manresa  3 Michelin stars
# 1917      NaN    NaN                         maum   1 Michelin star
# 1918      NaN    NaN                 michael mina   1 Michelin star
# 1919      NaN    NaN                       mourad   1 Michelin star
# 1920      NaN    NaN                         nico   1 Michelin star
# 1921      NaN    NaN                 plumed horse   1 Michelin star
# 1922      NaN    NaN                      protegé   1 Michelin star
# 1923      NaN    NaN                         rasa   1 Michelin star
# 1924      NaN    NaN                 singlethread  3 Michelin stars
# 1925      NaN    NaN              sushi yoshizumi   1 Michelin star
# 1926      NaN    NaN           the french laundry  3 Michelin stars
# 1927      NaN    NaN  the restaurant at meadowood  3 Michelin stars
# 1928      NaN    NaN              the village pub   1 Michelin star
# 1929      NaN    NaN                         wako   1 Michelin star
# 1930      NaN    NaN                     wakuriya   1 Michelin star

# %%
# wako japanese restaurant
SF_Wiki['Name'] = SF_Wiki.Name.replace('wako','wako japanese restaurant')

# mourad restaurant
SF_Wiki['Name'] = SF_Wiki.Name.replace('mourad','mourad restaurant')

# %%
# PH_SF[PH_SF.name.str.contains('farmhouse')]

# %%
SF_PW = (pd
         .merge(left = PH_SF,
                right = SF_Wiki,
                how = "left",
                left_on = "name",
                right_on = "Name")
         .drop("Name", axis = 1)
         .rename(columns = {"2019":"michelin_star"}))

# %%
SF_PW['michelin_star'] = SF_PW.michelin_star.fillna(0)
SF_PW['michelin_star'] = SF_PW.michelin_star.replace('1 Michelin star',1)
SF_PW['michelin_star'] = SF_PW.michelin_star.replace('2 Michelin stars',2)
SF_PW['michelin_star'] = SF_PW.michelin_star.replace('3 Michelin stars',3)

# %%
SF_Wiki.shape
# Out:
# (62, 2)

# %%
SF_PW.query('michelin_star != 0').shape
# Out:
# (34, 11)

# %% [markdown]
# ## Clean PH_LA

# %%
# Read in the data
PH_LA = pd.read_csv("Data/ParseHub/PH_LA.csv")

# Print the shape of the data
PH_LA.shape
# Out:
# (5348, 9)

# %%
PH_LA = PH_clean(PH_LA,region="California")
PH_LA.shape
# Out:
# (3109, 10)

# %% [markdown]
# ## Merge PH_LA and LA_Wiki

# %%
# Read in the data
LA_Wiki = pd.read_csv("Data/Wikipedia/Wiki_LA.csv")
LA_Wiki = LA_Wiki.drop(list(LA_Wiki.columns)[1:-1],axis=1)
LA_Wiki.dropna(subset=['2019'],inplace=True)
LA_Wiki['Name'] = LA_Wiki['Name'].str.lower()
LA_Wiki
# Out:
#                     Name              2019
# 0                addison   1 Michelin star
# 3            bistro na's   1 Michelin star
# 4   cut by wolfgang puck   1 Michelin star
# 5               dialogue   1 Michelin star
# 6                hana re   1 Michelin star
# 8                 hayato   1 Michelin star
# 10                  kali   1 Michelin star
# 11                  kato   1 Michelin star
# 14           le comptoir   1 Michelin star
# 16                 maude   1 Michelin star
# 18            mori sushi   1 Michelin star
# 19                n/naka  2 Michelin stars
# 20            nozawa bar   1 Michelin star
# 21        orsa & winston   1 Michelin star
# 23         osteria mozza   1 Michelin star
# 24            providence  2 Michelin stars
# 26               q sushi   1 Michelin star
# 27         rustic canyon   1 Michelin star
# 29               shibumi   1 Michelin star
# 30            shin sushi   1 Michelin star
# 31                shunji   1 Michelin star
# 32                 somni  2 Michelin stars
# 35   sushi ginza onodera  2 Michelin stars
# 37            taco maria   1 Michelin star
# 38             trois mec   1 Michelin star
# 40               urasawa  2 Michelin stars
# 42            vespertine  2 Michelin stars

# %%
# Anti merge
m = (pd
     .merge(left = PH_LA, 
            right = LA_Wiki, 
            how = 'outer', 
            left_on = "name", 
            right_on = "Name",
            indicator = True))
m.loc[m._merge=="right_only",:].drop(columns="_merge")
# Out:
#      name  url phone address rating  review_count neighborhood  price_range  \
# 3109  NaN  NaN   NaN     NaN    NaN           NaN          NaN          NaN
# 3110  NaN  NaN   NaN     NaN    NaN           NaN          NaN          NaN
# 3111  NaN  NaN   NaN     NaN    NaN           NaN          NaN          NaN
# 3112  NaN  NaN   NaN     NaN    NaN           NaN          NaN          NaN
# 3113  NaN  NaN   NaN     NaN    NaN           NaN          NaN          NaN
# 3114  NaN  NaN   NaN     NaN    NaN           NaN          NaN          NaN
# 3115  NaN  NaN   NaN     NaN    NaN           NaN          NaN          NaN
# 3116  NaN  NaN   NaN     NaN    NaN           NaN          NaN          NaN
#
#      category region                  Name              2019
# 3109      NaN    NaN               addison   1 Michelin star
# 3110      NaN    NaN  cut by wolfgang puck   1 Michelin star
# 3111      NaN    NaN              dialogue   1 Michelin star
# 3112      NaN    NaN               hana re   1 Michelin star
# 3113      NaN    NaN                  kali   1 Michelin star
# 3114      NaN    NaN                shunji   1 Michelin star
# 3115      NaN    NaN             trois mec   1 Michelin star
# 3116      NaN    NaN               urasawa  2 Michelin stars

# %%
# cut
LA_Wiki['Name'] = LA_Wiki.Name.replace('cut by wolfgang puck','cut')

# shunji japanese cuisine
LA_Wiki['Name'] = LA_Wiki.Name.replace('shunji','shunji japanese cuisine')

# kali restaurant
LA_Wiki['Name'] = LA_Wiki.Name.replace('kali','kali restaurant')

# hanare sushi
LA_Wiki['Name'] = LA_Wiki.Name.replace('hana re','hanare sushi')

# %%
# PH_LA[PH_LA.name.str.contains('trois')]

# %%
# Anti merge
m = (pd
     .merge(left = PH_LA, 
            right = LA_Wiki, 
            how = 'outer', 
            left_on = "name", 
            right_on = "Name",
            indicator = True))
m.loc[m._merge=="right_only",:].drop(columns="_merge")
# Out:
#      name  url phone address rating  review_count neighborhood  price_range  \
# 3109  NaN  NaN   NaN     NaN    NaN           NaN          NaN          NaN
# 3110  NaN  NaN   NaN     NaN    NaN           NaN          NaN          NaN
# 3111  NaN  NaN   NaN     NaN    NaN           NaN          NaN          NaN
# 3112  NaN  NaN   NaN     NaN    NaN           NaN          NaN          NaN
#
#      category region       Name              2019
# 3109      NaN    NaN    addison   1 Michelin star
# 3110      NaN    NaN   dialogue   1 Michelin star
# 3111      NaN    NaN  trois mec   1 Michelin star
# 3112      NaN    NaN    urasawa  2 Michelin stars

# %%
LA_PW = (pd
         .merge(left = PH_LA,
                right = LA_Wiki,
                how = "left",
                left_on = "name",
                right_on = "Name")
         .drop("Name", axis = 1)
         .rename(columns = {"2019":"michelin_star"}))

# %%
LA_PW['michelin_star'] = LA_PW.michelin_star.fillna(0)
LA_PW['michelin_star'] = LA_PW.michelin_star.replace('1 Michelin star',1)
LA_PW['michelin_star'] = LA_PW.michelin_star.replace('2 Michelin stars',2)
LA_PW['michelin_star'] = LA_PW.michelin_star.replace('3 Michelin stars',3)

# %%
LA_Wiki.shape
# Out:
# (27, 2)

# %%
LA_PW.query('michelin_star != 0').shape
# Out:
# (23, 11)

# %%
CA_PW = pd.concat([SF_PW,LA_PW],sort=False)
CA_PW.sample(5)
# Out:
#                                   name  \
# 137   pollos asados al carbón el güero
# 267                            redbird
# 1718                       uncle tetsu
# 814           la michoacana restaurant
# 29       sotto mare oysteria & seafood
#
#                                                     url           phone  \
# 137   https://www.yelp.com/biz/pollos-asados-al-carb...        Florence
# 267      https://www.yelp.com/biz/redbird-los-angeles-2  (213) 788-1191
# 1718    https://www.yelp.com/biz/uncle-tetsu-torrance-2  (323) 275-9190
# 814   https://www.yelp.com/biz/la-michoacana-restaur...  (323) 505-0120
# 29    https://www.yelp.com/biz/sotto-mare-oysteria-a...  (415) 398-3181
#
#                                      address rating  review_count  \
# 137                        274 E Slauson Ave      4            37
# 267                             114 E 2nd St      4          1474
# 1718                       3525 W Carson St.    4.5           192
# 814                 1625 East Cesar Chavez E      4            27
# 29    Located in Dante Benedetti Hotel & Sro    4.5          3837
#
#                                 neighborhood  price_range  \
# 137                                      NaN          1.0
# 267                                 Downtown          3.0
# 1718                                     NaN          1.0
# 814                            Boyle Heights          2.0
# 29    Located in Dante Benedetti Hotel & Sro          2.0
#
#                                                category      region  \
# 137                                           [Mexican]  California
# 267   [Cocktail Bars, American (New), Breakfast & Br...  California
# 1718                               [Desserts, Japanese]  California
# 814                                  [Mexican, Seafood]  California
# 29                             [Seafood, Italian, Bars]  California
#
#       michelin_star
# 137               0
# 267               0
# 1718              0
# 814               0
# 29                0

# %% [markdown]
# ## Merge CA_PW and Michelin

# %%
CA_MG = Michelin.loc[Michelin['region'] == "California"].drop(['region','url'],axis=1)
CA_MG['name'] = CA_MG.name.str.replace('’',"'")
CA_MG['name'] = CA_MG['name'].str.lower()
CA_MG.shape
# Out:
# (624, 2)

# %%
# Anti merge
m = (pd
     .merge(left = CA_PW, 
            right = CA_MG, 
            how = 'outer', 
            on = "name",  
            indicator = True))
m.loc[m._merge=="right_only",:].drop(columns="_merge")
# Out:
#                  name  url phone address rating  review_count neighborhood  \
# 5012     café romanat  NaN   NaN     NaN    NaN           NaN          NaN
# 5013            dyafa  NaN   NaN     NaN    NaN           NaN          NaN
# 5014          cultura  NaN   NaN     NaN    NaN           NaN          NaN
# 5015      cowboy star  NaN   NaN     NaN    NaN           NaN          NaN
# 5016        el jardín  NaN   NaN     NaN    NaN           NaN          NaN
# ...               ...  ...   ...     ...    ...           ...          ...
# 5450  sushi yoshizumi  NaN   NaN     NaN    NaN           NaN          NaN
# 5451        shakewell  NaN   NaN     NaN    NaN           NaN          NaN
# 5452     the fig café  NaN   NaN     NaN    NaN           NaN          NaN
# 5453           villon  NaN   NaN     NaN    NaN           NaN          NaN
# 5454     dametra cafe  NaN   NaN     NaN    NaN           NaN          NaN
#
#       price_range category region  michelin_star  michelin_guide
# 5012          NaN      NaN    NaN            NaN             1.0
# 5013          NaN      NaN    NaN            NaN             1.0
# 5014          NaN      NaN    NaN            NaN             1.0
# 5015          NaN      NaN    NaN            NaN             1.0
# 5016          NaN      NaN    NaN            NaN             1.0
# ...           ...      ...    ...            ...             ...
# 5450          NaN      NaN    NaN            NaN             1.0
# 5451          NaN      NaN    NaN            NaN             1.0
# 5452          NaN      NaN    NaN            NaN             1.0
# 5453          NaN      NaN    NaN            NaN             1.0
# 5454          NaN      NaN    NaN            NaN             1.0
#
# [443 rows x 12 columns]

# %%
# CH_PW[CH_PW.name.str.contains('tocaya')]

# %%
CA = (pd
      .merge(left = CA_PW,
             right = CA_MG,
             how = "left",
             on = "name",))

# %%
# Fill NaN in michelin_guide with 0
CA['michelin_guide'] = CA['michelin_guide'].fillna(0)
CA['michelin_guide'] = CA['michelin_guide'].astype(int)

star = CA[CA.michelin_star != 0].index
CA['michelin_guide'].loc[star] = 1

# %%
# Export to a CSV file
CA.to_csv('Data/CA.csv',index=False)
