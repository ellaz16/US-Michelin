# %% [markdown]
# ## Preparation

# %%
# Data processing
import pandas as pd
import numpy as np
import re

# Scraping web content
import requests # For downloading the website
from bs4 import BeautifulSoup # For parsing the website
import time # To put the system to sleep
import random # For random numbers

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Scrape Wiki DC

# %%
# Wiki DC Michelin url
url = 'https://en.wikipedia.org/wiki/List_of_Michelin_starred_restaurants_in_Washington,_D.C.'

# Download the webpage
page = requests.get(url)
page.status_code # 200 == Connection
# Out:
# 200

# %%
# Parse the content
soup = BeautifulSoup(page.content,'html.parser')

# %%
# Title of the wiki page
soup.title.string
# Out:
# 'List of Michelin starred restaurants in Washington, D.C. - Wikipedia'

# %%
# Get the right table
table = soup.find('table',{'class':'wikitable sortable'})

# %%
# Get the rows
rows = table.find_all('tr')
len(rows)
# Out:
# 21

# %%
# Get the table header attributes
header = ([th.text.rstrip() for th in rows[0].find_all('th')] + 
          [re.sub(r'\(.*?\)\[.*?\]','',td.text).rstrip() for td in rows[0].find_all('td')])
header
# Out:
# ['Name', 'Neighborhood/City', '2017', '2018', '2019', '2020']

# %%
# Build a function to extract star rating from an individual cell
def get_star(cell):
    """
    This is a function that takes cell as an input and output its value.
    """
    try:
        value = cell.find_all('img')[0]['alt']
    except IndexError:
        value = np.nan
    
    return value

# %%
# Create an empty DataFrame
Wiki_DC = pd.DataFrame(columns=header)

# Scrape and save to DataFrame
for row in rows[1:]:
    
    cells = row.find_all('td')
    
    Wiki_DC = Wiki_DC.append({header[0]:cells[0].text.rstrip(),
                              header[1]:cells[1].text.rstrip(),
                              header[2]:get_star(cells[2]),
                              header[3]:get_star(cells[3]),
                              header[4]:get_star(cells[4]),
                              header[5]:get_star(cells[5])},
                             ignore_index=True)

Wiki_DC
# Out:
#                         Name    Neighborhood/City              2017  \
# 0           Blue Duck Tavern             West End   1 Michelin star
# 1                     Bresca         Logan Circle               NaN
# 2                      Fiola         Penn Quarter   1 Michelin star
# 3                   Gravitas             Ivy City               NaN
# 4   Inn at Little Washington       Washington, VA  2 Michelin stars
# 5                    Kinship  Mount Vernon Square   1 Michelin star
# 6                       Komi        Dupont Circle               NaN
# 7                     Maydan             U Street               NaN
# 8                   Masseria         Union Market   1 Michelin star
# 9               Little Pearl       Eastern Market               NaN
# 10                    Métier  Mount Vernon Square               NaN
# 11                   minibar         Penn Quarter  2 Michelin stars
# 12        Pineapple & Pearls       Eastern Market  2 Michelin stars
# 13                     Plume             Downtown   1 Michelin star
# 14             Rose's Luxury       Eastern Market   1 Michelin star
# 15                     Siren         Logan Circle               NaN
# 16            Sushi Nakazawa             Downtown               NaN
# 17                Sushi Taro        Dupont Circle   1 Michelin star
# 18              Tail Up Goat         Adams Morgan   1 Michelin star
# 19                The Dabney                 Shaw   1 Michelin star
#
#                 2018              2019              2020
# 0    1 Michelin star   1 Michelin star               NaN
# 1                NaN   1 Michelin star   1 Michelin star
# 2    1 Michelin star   1 Michelin star   1 Michelin star
# 3                NaN               NaN   1 Michelin star
# 4   2 Michelin stars  3 Michelin stars  3 Michelin stars
# 5    1 Michelin star   1 Michelin star   1 Michelin star
# 6    1 Michelin star   1 Michelin star   1 Michelin star
# 7                NaN               NaN   1 Michelin star
# 8    1 Michelin star   1 Michelin star   1 Michelin star
# 9                NaN               NaN   1 Michelin star
# 10   1 Michelin star   1 Michelin star   1 Michelin star
# 11  2 Michelin stars  2 Michelin stars  2 Michelin stars
# 12  2 Michelin stars  2 Michelin stars  2 Michelin stars
# 13   1 Michelin star   1 Michelin star   1 Michelin star
# 14   1 Michelin star   1 Michelin star   1 Michelin star
# 15               NaN   1 Michelin star               NaN
# 16               NaN               NaN   1 Michelin star
# 17   1 Michelin star   1 Michelin star   1 Michelin star
# 18   1 Michelin star   1 Michelin star   1 Michelin star
# 19   1 Michelin star   1 Michelin star   1 Michelin star

# %%
# Export to a CSV file
Wiki_DC.to_csv('Data/Wikipedia/Wiki_DC.csv',index=False)

# %% [markdown]
# ## Scrape Wiki Chicago

# %%
# Wiki Chicago Michelin url
url = 'https://en.wikipedia.org/wiki/List_of_Michelin_starred_restaurants_in_Chicago'

# Download the webpage
page = requests.get(url)
page.status_code # 200 == Connection
# Out:
# 200

# %%
# Parse the content
soup = BeautifulSoup(page.content,'html.parser')

# %%
# Title of the wiki page
soup.title.string
# Out:
# 'List of Michelin starred restaurants in Chicago - Wikipedia'

# %%
# Get the right table
table = soup.find('table',{'class':'wikitable sortable'})

# %%
# Get the rows
rows = table.find_all('tr')
len(rows)
# Out:
# 51

# %%
# Get the table header attributes
header = [re.sub(r'\(.*?\)\[.*?\]','',th.text).rstrip() for th in rows[0].find_all('th')]
header
# Out:
# ['Name',
#  'Neighborhood/City',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020']

# %%
# Get the length of the header
len(header)
# Out:
# 12

# %%
# Update get_star function to a deluxe edition
def get_star_deluxe(cells=None,i=None):
    """
    This is a a deluxe edition of the get_star function.
    """
    try:
        value = cells[i].find_all('img')[0]['alt']
    except IndexError:
        value = np.nan
    
    return value

# %%
# Create an empty DataFrame
Wiki_Chicago = pd.DataFrame(columns=header)

# Scrape and save to DataFrame
for row in rows[1:]:
    
    cells = row.find_all('td')
    
    Wiki_Chicago = Wiki_Chicago.append({header[0]:cells[0].text.rstrip(),
                                        header[1]:cells[1].text.rstrip(),
                                        header[2]:get_star_deluxe(cells,2),
                                        header[3]:get_star_deluxe(cells,3),
                                        header[4]:get_star_deluxe(cells,4),
                                        header[5]:get_star_deluxe(cells,5),
                                        header[6]:get_star_deluxe(cells,6),
                                        header[7]:get_star_deluxe(cells,7),
                                        header[8]:get_star_deluxe(cells,8),
                                        header[9]:get_star_deluxe(cells,9),
                                        header[10]:get_star_deluxe(cells,10),
                                        header[11]:get_star_deluxe(cells,11)},
                             ignore_index=True)

Wiki_Chicago
# Out:
#                     Name Neighborhood/City              2011  \
# 0               42 Grams            Uptown               NaN
# 1                 Acadia        South Loop               NaN
# 2                 Alinea      Lincoln Park  3 Michelin stars
# 3                Avenues  Magnificent Mile  2 Michelin stars
# 4        Band of Bohemia        Ravenswood               NaN
# 5              Blackbird         West Loop   1 Michelin star
# 6                   Boka      Lincoln Park   1 Michelin star
# 7              Bonsoirée      Logan Square   1 Michelin star
# 8      Charlie Trotter's      Lincoln Park  2 Michelin stars
# 9       Crofton on Wells       River North   1 Michelin star
# 37               NaN
# 38               NaN
# 39   1 Michelin star
# 40               NaN
# 41  2 Michelin stars
# 42   1 Michelin star
# 43               NaN
# 44   1 Michelin star
# 45   1 Michelin star
# 46               NaN
# 47               NaN
# 48               NaN
# 49   1 Michelin star

# %%
# Export to a CSV file
Wiki_Chicago.to_csv('Data/Wikipedia/Wiki_Chicago.csv',index=False)

# %% [markdown]
# ## Scrape Wiki NY

# %%
# Wiki NY Michelin url
url = 'https://en.wikipedia.org/wiki/List_of_Michelin_starred_restaurants_in_New_York_City'

# Download the webpage
page = requests.get(url)
page.status_code # 200 == Connection
# Out:
# 200

# %%
# Parse the content
soup = BeautifulSoup(page.content,'html.parser')

# %%
# Title of the wiki page
soup.title.string
# Out:
# 'List of Michelin starred restaurants in New York City - Wikipedia'

# %%
# Get the right table
table = soup.find('table',{'class':'wikitable sortable'})

# %%
# Get the rows
rows = table.find_all('tr')
len(rows)
# Out:
# 177

# %%
# Get the table header attributes
pat1 = r'\(.*?\)\[.*?\]\[.*?\]'
pat2 = r'\(.*?\)\[.*?\]'
com_pat = r'|'.join((pat1, pat2))
header = [re.sub(com_pat,'',th.text).rstrip() for th in rows[0].find_all('th')]
header
# Out:
# ['Name',
#  'Borough/County',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020']

# %%
# Get the length of the header
len(header)
# Out:
# 17

# %%
# Create an empty DataFrame
Wiki_NY = pd.DataFrame(columns=header)

# Scrape and save to DataFrame
for row in rows[1:]:
    
    cells = row.find_all('td')
    
    Wiki_NY = Wiki_NY.append({header[0]:cells[0].text.rstrip(),
                              header[1]:cells[1].text.rstrip(),
                              header[2]:get_star_deluxe(cells,2),
                              header[3]:get_star_deluxe(cells,3),
                              header[4]:get_star_deluxe(cells,4),
                              header[5]:get_star_deluxe(cells,5),
                              header[6]:get_star_deluxe(cells,6),
                              header[7]:get_star_deluxe(cells,7),
                              header[8]:get_star_deluxe(cells,8),
                              header[9]:get_star_deluxe(cells,9),
                              header[10]:get_star_deluxe(cells,10),
                              header[11]:get_star_deluxe(cells,11),
                              header[12]:get_star_deluxe(cells,12),
                              header[13]:get_star_deluxe(cells,13),
                              header[14]:get_star_deluxe(cells,14),
                              header[15]:get_star_deluxe(cells,15),
                              header[16]:get_star_deluxe(cells,16)},
                             ignore_index=True)

Wiki_NY
# Out:
#                 Name Borough/County             2006             2007  \
# 0            15 East      Manhattan              NaN              NaN
# 1    A Voce Columbus      Manhattan              NaN  1 Michelin star
# 2     A Voce Madison      Manhattan              NaN              NaN
# 3              Adour      Manhattan              NaN              NaN
# 4              Agern      Manhattan              NaN              NaN
# ..               ...            ...              ...              ...
# 171             Vong      Manhattan  1 Michelin star  1 Michelin star
# 172           Wallsé      Manhattan  1 Michelin star  1 Michelin star
# 173            wd~50      Manhattan  1 Michelin star  1 Michelin star
# 174        Zabb Elee         Queens              NaN              NaN
# 175    ZZ's Clam Bar      Manhattan              NaN              NaN
#
#                 2008              2009             2010             2011  \
# 0                NaN               NaN              NaN              NaN
# 1    1 Michelin star               NaN  1 Michelin star  1 Michelin star
# 2                NaN               NaN              NaN  1 Michelin star
# 3                NaN  2 Michelin stars  1 Michelin star  1 Michelin star
# 4                NaN               NaN              NaN              NaN
# ..               ...               ...              ...              ...
# 171  1 Michelin star               NaN              NaN              NaN
# 172  1 Michelin star   1 Michelin star  1 Michelin star  1 Michelin star
# 173  1 Michelin star   1 Michelin star  1 Michelin star  1 Michelin star
# 174              NaN               NaN              NaN              NaN
# 175              NaN               NaN              NaN              NaN
#
#                 2012             2013             2014             2015  \
# 0                NaN  1 Michelin star  1 Michelin star  1 Michelin star
# 1    1 Michelin star  1 Michelin star  1 Michelin star              NaN
# 2    1 Michelin star  1 Michelin star  1 Michelin star              NaN
# 3    1 Michelin star  1 Michelin star              NaN              NaN
# 4                NaN              NaN              NaN              NaN
# ..               ...              ...              ...              ...
# 171              NaN              NaN              NaN              NaN
# 172  1 Michelin star  1 Michelin star  1 Michelin star  1 Michelin star
# 173  1 Michelin star  1 Michelin star  1 Michelin star              NaN
# 174              NaN              NaN              NaN  1 Michelin star
# 175              NaN              NaN              NaN  1 Michelin star
#
#                 2016             2017             2018             2019  \
# 0                NaN              NaN              NaN              NaN
# 1                NaN              NaN              NaN              NaN
# 2                NaN              NaN              NaN              NaN
# 3                NaN              NaN              NaN              NaN
# 4                NaN  1 Michelin star  1 Michelin star  1 Michelin star
# ..               ...              ...              ...              ...
# 171              NaN              NaN              NaN              NaN
# 172  1 Michelin star  1 Michelin star  1 Michelin star  1 Michelin star
# 173              NaN              NaN              NaN              NaN
# 174              NaN              NaN              NaN              NaN
# 175  1 Michelin star  1 Michelin star  1 Michelin star  1 Michelin star
#
#                 2020
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4    1 Michelin star
# ..               ...
# 171              NaN
# 172  1 Michelin star
# 173              NaN
# 174              NaN
# 175  1 Michelin star
#
# [176 rows x 17 columns]

# %%
# Export to a CSV file
Wiki_NY.to_csv('Data/Wikipedia/Wiki_NY.csv',index=False)

# %% [markdown]
# ## Scrape Wiki SF

# %%
# Wiki SF Michelin url
url = 'https://en.wikipedia.org/wiki/List_of_Michelin_starred_restaurants_in_San_Francisco_Bay_Area'

# Download the webpage
page = requests.get(url)
page.status_code # 200 == Connection
# Out:
# 200

# %%
# Parse the content
soup = BeautifulSoup(page.content,'html.parser')

# %%
# Title of the wiki page
soup.title.string
# Out:
# 'List of Michelin starred restaurants in San Francisco Bay Area - Wikipedia'

# %%
# Get the right table
table = soup.find('table',{'class':'wikitable sortable'})

# %%
# Get the rows
rows = table.find_all('tr')
len(rows)
# Out:
# 63

# %%
# Get the table header attributes
header = [re.sub(r'\(.*?\)\[.*?\]','',th.text).rstrip() for th in rows[0].find_all('th')]
header
# Out:
# ['Name', 'City/Neighborhood', '2019']

# %%
# Get the length of the header
len(header)
# Out:
# 3

# %%
# Create an empty DataFrame
Wiki_SF = pd.DataFrame(columns=header)

# Scrape and save to DataFrame
for row in rows[1:]:
    
    cells = row.find_all('td')
    
    Wiki_SF = Wiki_SF.append({header[0]:cells[0].text.rstrip(),
                              header[1]:cells[1].text.rstrip(),
                              header[2]:get_star(cells[2])},
                             ignore_index=True)

Wiki_SF
# Out:
#                            Name                   City/Neighborhood  \
# 0                    Acquerello          San Francisco - Polk Gulch
# 1                    Al's Place    San Francisco - Mission District
# 2                        Angler  San Francisco - Financial District
# 3             Auberge du Soleil                          Rutherford
# 4                     Aubergine                            Monterey
# ..                          ...                                 ...
# 57                 The Progress            San Francisco - Fillmore
# 58  The Restaurant at Meadowood                          St. Helena
# 59              The Village Pub                            Woodside
# 60                         Wako   San Francisco - Richmond District
# 61                     Wakuriya                           San Mateo
#
#                 2019
# 0   2 Michelin stars
# 1    1 Michelin star
# 2    1 Michelin star
# 3    1 Michelin star
# 4    1 Michelin star
# ..               ...
# 57   1 Michelin star
# 58  3 Michelin stars
# 59   1 Michelin star
# 60   1 Michelin star
# 61   1 Michelin star
#
# [62 rows x 3 columns]

# %%
# Export to a CSV file
Wiki_SF.to_csv('Data/Wikipedia/Wiki_SF.csv',index=False)

# %% [markdown]
# ## Scrape Wiki LA

# %%
# Wiki LA Michelin url
url = 'https://en.wikipedia.org/wiki/List_of_Michelin_starred_restaurants_in_Los_Angeles'

# Download the webpage
page = requests.get(url)
page.status_code # 200 == Connection
# Out:
# 200

# %%
# Parse the content
soup = BeautifulSoup(page.content,'html.parser')

# %%
# Title of the wiki page
soup.title.string
# Out:
# 'List of Michelin starred restaurants in Los Angeles - Wikipedia'

# %%
# Get the right table
table = soup.find('table',{'class':'wikitable sortable'})

# %%
# Get the rows
rows = table.find_all('tr')
len(rows)
# Out:
# 45

# %%
# Get the table header attributes
header = [re.sub(r'\[.*?\]','',th.text).rstrip() for th in rows[0].find_all('th')]
header
# Out:
# ['Name', 'City/Neighborhood', '2008', '2009', 'No Guide (2010-2018)', '2019']

# %%
# Get the length of the header
len(header)
# Out:
# 6

# %%
# Create an empty DataFrame
Wiki_LA = pd.DataFrame(columns=header)

# Scrape and save to DataFrame
for row in rows[1:]:
    
    cells = row.find_all('td')
    
    Wiki_LA = Wiki_LA.append({header[0]:cells[0].text.rstrip(),
                              header[1]:cells[1].text.rstrip(),
                              header[2]:get_star_deluxe(cells,2),
                              header[3]:get_star_deluxe(cells,3),
                              header[4]:get_star_deluxe(cells,4),
                              header[5]:get_star_deluxe(cells,5)},
                             ignore_index=True)

Wiki_LA
# Out:
#                                      Name          City/Neighborhood  \
# 0                                 Addison                  San Diego
# 1                                 Asanebo  Los Angeles - Studio City
# 2                                 Bastide             West Hollywood
# 3                             Bistro Na's                Temple City
# 4                    CUT by Wolfgang Puck              Beverly Hills
# 5                                Dialogue               Santa Monica
# 6                                 Hana Re                 Costa Mesa
# 7                              Hatfield's                Los Angeles
# 8                                  Hayato                Los Angeles
# 9                        Joe's Restaurant       Los Angeles - Venice
# 10                                   Kali                Los Angeles
# 11                                   Kato                Los Angeles
# 12                               La Botte               Santa Monica
# 13  Dining Room at the Langham Huntington                   Pasadena
# 14                            Le Comptoir                Los Angeles
# 15                              Matsuhisa              Beverly Hills
# 16                                  Maude                Los Angeles
# 17                                Mélisse               Santa Monica
# 18                             Mori Sushi                Los Angeles
# 19                                 n/naka                Los Angeles
# 20                             Nozawa Bar              Beverly Hills
# 21                         Orsa & Winston                Los Angeles
# 22                                Ortolan                Los Angeles
# 23                          Osteria Mozza                Los Angeles
# 24                             Providence    Los Angeles - Hollywood
# 25                                 Patina                Los Angeles
# 26                                Q Sushi                Los Angeles
# 27                          Rustic Canyon                Los Angeles
